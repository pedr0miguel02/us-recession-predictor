# %% [markdown]
# # 01 — Recolha de dados (FRED)
#
# Recolhe as séries macro definidas em `config.yaml` e inspeciona os dados brutos.

# %%
import sys; sys.path.append('..')
from src.fetch_data import load_config, fetch_series
import pandas as pd

# %%
config = load_config('../config.yaml')
df = fetch_series(config)
df.tail()
# Out:
#   - a recolher yield_10y3m    (T10Y3M) ...
#   - a recolher unemployment   (UNRATE) ...
#   - a recolher industrial     (INDPRO) ...
#   - a recolher cpi            (CPIAUCSL) ...
#   - a recolher fed_funds      (FEDFUNDS) ...
#   - a recolher m2             (M2SL) ...
#   - a recolher consumer_sent  (UMCSENT) ...
#   - a recolher recession      (USREC) ...
#             yield_10y3m  unemployment  industrial      cpi  fed_funds  \
# 2026-02-01         0.30           4.4    101.9493  327.460       3.64
# 2026-03-01         0.60           4.3    101.6273  330.293       3.64
# 2026-04-01         0.72           4.3    102.5090  332.407       3.64
# 2026-05-01         0.76           4.3    102.6475  333.979       3.63
# 2026-06-01         0.68           NaN         NaN      NaN        NaN
#
#                  m2  consumer_sent  recession
# 2026-02-01  22627.0           56.6        0.0
# 2026-03-01  22686.4           53.3        0.0
# 2026-04-01  22804.5           49.8        0.0
# 2026-05-01      NaN            NaN        0.0
# 2026-06-01      NaN            NaN        0.0

# %%
df.describe()
# Out:
#        yield_10y3m  unemployment  industrial         cpi   fed_funds  \
# count   534.000000    676.000000  677.000000  676.000000  677.000000
# mean      1.527135      6.046302   75.895382  164.208925    4.889749
# std       1.251030      1.714470   22.595027   78.319203    3.831794
# min      -1.880000      3.400000   36.451400   37.900000    0.050000
# 25%       0.590000      4.700000   53.331800  102.475000    1.680000
# 50%       1.580000      5.700000   84.488000  162.000000    4.910000
# 75%       2.510000      7.200000   98.745700  228.540500    6.780000
# max       4.090000     14.800000  104.100400  333.979000   19.100000
#
#                  m2  consumer_sent   recession
# count    676.000000     612.000000  678.000000
# mean    6810.548669      83.685784    0.125369
# std     6239.091714      13.724476    0.331381
# min      586.300000      49.800000    0.000000
# 25%     2153.200000      73.100000    0.000000
# 50%     4101.600000      86.950000    0.000000
# 75%     9867.350000      93.925000    0.000000
# max    22804.500000     112.000000    1.000000

# %%
# Quantos meses de recessão no histórico?
df['recession'].value_counts(normalize=True)
# Out:
# recession
# 0.0    0.874631
# 1.0    0.125369
# Name: proportion, dtype: float64
